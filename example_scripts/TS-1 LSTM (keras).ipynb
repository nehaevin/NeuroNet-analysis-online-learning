# %% [markdown]
# # Фильтрация и анализ данных из подготовленной таблицы динамики признаков с использованием LSTM из tf.keras
# -------
#
# **Дано:**
# - имеется таблица, фиксирующая изменение всех важных признаков/фичей во времени (фичи генерировались и подбирались на предыдущем этапе);
# - индексом таблицы является дата-время либо в виде TimeStamp либо в виде DateTime;
# - все фичи закодированы численно либо как one-hot enc (категориальные фичи).
#
# **Требуется:**
# - разработать pipeline для эмбеддинга, кодирования окон изменения фичей с использованием AE или VAE;
# - разработать функционал визуального анализа структуры кластеров кодов и соответствующих им окон;
# - исследовать как архитектура сверточных слоев AE влияет на кодирование окон;
# - выявить основные типы окон, которые может кодировать/распознавать/выделять АЭ в зависимости от его архитектуры.

# %%
# подключаем колаб к нашему гугл-диску
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# устанавливаем рабочую директорию/каталог
import os

path = "/content/drive/My Drive/Colab Notebooks/Moneta/"
os.chdir(path)
# print(os.listdir())

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tseries.offsets import *
import seaborn as sbn
np.set_printoptions(precision=3)

import datetime as dt
print('Last Updated On: ', dt.datetime.now().date())

import sys

""" параметры графиков """
plt.style.use('ggplot')
plt.rcParams['font.fantasy'] = 'Arial', 'Times New Roman', 'Tahoma', 'Comic Sans MS', 'Courier'
# Out:
# Last Updated On:  2023-02-08

# %% [markdown]
# # ПЛАН РАБОТ
# ---
#
# 1. Считываем и делаем визуальный анализ попарных зависимостей данных
# 1. Выбираем ширину окна. Формируем датасет и даталоадер для обучения и тестирования АЭ.
# 1. Строим АЭ с выделением энкодера и декодера в отдельную нейросеть
# 1. Обучаем АЭ
# 1. Кодируем энкодером окна
# 1. Кластеризуем окна; выбираем наилучший метод и параметры силуэтным анализом (k-means, )
# 1. Делаем проекцию tSNE и визуализируем кластерную структуру
# 1. Проводим анализ получившихся кластеров окон

# %% [markdown]
# ## **Считываем данные**
# ---
#
# Подготовленные данные
#
# datetime|	val_00 | val_01 | ...
# --- | --- | --- | ---
# 01.01.2009|	29,3916 | -0.108 | ...
# 12.01.2009|	30,5331 | 1.1415 | ...

# %%
prep_df = pd.read_csv('data/dollar_prepared.csv', header=0, sep=';', index_col=0) # 
print(prep_df.shape)
prep_df.tail(5)
# Out:
# (5052, 11)
#              dollar  d_dollar  day_of_week_0  day_of_week_1  day_of_week_2  \
# datetime
# 2022-10-27  61.4012   -0.0743              0              0              0
# 2022-10-28  61.5294    0.1282              0              0              0
# 2022-10-29  61.5294    0.0000              0              0              0
# 2022-10-30  61.5294    0.0000              0              0              0
# 2022-10-31  61.6277    0.0983              1              0              0
#
#             day_of_week_3  day_of_week_4  day_of_week_5  day_of_week_6  \
# datetime
# 2022-10-27              1              0              0              0
# 2022-10-28              0              1              0              0
# 2022-10-29              0              0              1              0
# 2022-10-30              0              0              0              1
# 2022-10-31              0              0              0              0
#
#             sin_month     cos_month
# datetime
# 2022-10-27       -1.0 -1.836970e-16
# 2022-10-28       -1.0 -1.836970e-16
# 2022-10-29       -1.0 -1.836970e-16
# 2022-10-30       -1.0 -1.836970e-16
# 2022-10-31       -1.0 -1.836970e-16

# %%
import datetime as dt

prep_df.index = pd.to_datetime(prep_df.index)
prep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5052 entries, 2009-01-01 to 2022-10-31
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dollar         5052 non-null   float64
#  1   d_dollar       5052 non-null   float64
#  2   day_of_week_0  5052 non-null   int64
#  3   day_of_week_1  5052 non-null   int64
#  4   day_of_week_2  5052 non-null   int64
#  5   day_of_week_3  5052 non-null   int64
#  6   day_of_week_4  5052 non-null   int64
#  7   day_of_week_5  5052 non-null   int64
#  8   day_of_week_6  5052 non-null   int64
#  9   sin_month      5052 non-null   float64
#  10  cos_month      5052 non-null   float64
# dtypes: float64(4), int64(7)
# memory usage: 473.6 KB

# %%
plt.figure(figsize=(18,6))

plt.plot(prep_df.d_dollar.index, prep_df.d_dollar.values);

# %% [markdown]
# ## **Визуальный анализ и выбор признаков**
# ---
# Выделим из загруженной таблицы поля, которые будем использовать для анализа
#
# Также выделим временные границы для последующей работы: возможно, нет смысла использовать динамику курса до 2014 года - она была совсем другой. Также мы можем убрать из обучающей выборки данные 2022 года, чтобы посмотреть как будет эмбеддить сеть резкие скачки (аномалии)

# %%
# Устанавливаем границы выбора данных для обучающей и тестовой выборок

train_start = dt.datetime(year=2014, month=1, day=1)
train_end = dt.datetime(year=2022, month=1, day=1)
test_start = train_end
test_end = prep_df.index[-1]

train_cond = prep_df.index <= train_end
train_cond = train_cond & (prep_df.index >= train_start)
test_cond = prep_df.index >= test_start
test_cond = test_cond & (prep_df.index <= test_end)

len(prep_df), sum(train_cond), sum(test_cond)
# Out:
# (5052, 2923, 304)

# %%
plt.figure(figsize=(16, 6))
ax1 = plt.subplot(221)
ax1.plot(prep_df.dollar.loc[train_cond])
ax1.set_title('dollar course (train)')
ax2 = plt.subplot(222)
ax2.plot(prep_df.d_dollar.loc[train_cond])
ax2.set_title('dollar course delta (train)')

ax3 = plt.subplot(223)
ax3.plot(prep_df.dollar.loc[test_cond])
ax3.set_title('dollar course (test)')
ax4 = plt.subplot(224)
ax4.plot(prep_df.d_dollar.loc[test_cond])
ax4.set_title('dollar course delta (test)')

plt.show()

# %%
# посмотрим на парные зависимости между параметрами

# выберем параметры
features = ['dollar', 'd_dollar', 'day_of_week_0', 'day_of_week_5', 'day_of_week_6', 'sin_month']
# sbn.pairplot(prep_df.loc[train_cond, features]);

# %% [markdown]
# resume:
#
# - необходимо шкалировать чисто числовые признаки, так как они имеют разный разброс;
# - есть статистическая зависимость между сезоном (месяцем) и диапазоном и средним изменений d_dollar;
# - видим, что на изменение курса доллара влияет фактор выходного дня;

# %% [markdown]
# ### Фильтруем признаки и данные
# ---
# - Выберем после результатов анализа зависимостей признаки, которые оказывают влияние на изменение основной величины (курса доллара); вектора с данными признаками будут подаваться на вход АЭ;
#
# - также укажем конкретно какие признаки мы хотим эмбеддить/кодировать (остальные признаки будут вспомогательными для кодирования); эта информация будет использоваться для обучении АЭ при оценке лосса (будем требовать восстановления только данных целевых признаков);
#
# - оформим все данные в виде отдельной таблицы df и тензора data; его далее мы и будем использовать как источника для формирования последовательностей векторов для обучения автоэнкодера;

# %%
# уточняем признаки, с которыми далее будем работать
prep_df.columns
features = ['dollar', 'd_dollar', 'day_of_week_5', 'day_of_week_6', 'sin_month']
# уточняем целевые признаки, которые хотим кодировать/воспроизводить
goal_features = ['dollar', 'd_dollar']
goal_indexes = [features.index(x) for x in goal_features]
print(goal_indexes)
# Out:
# [0, 1]

# %%
df = prep_df[features]
df.tail(3)
# Out:
#              dollar  d_dollar  day_of_week_5  day_of_week_6  sin_month
# datetime
# 2022-10-29  61.5294    0.0000              1              0       -1.0
# 2022-10-30  61.5294    0.0000              0              1       -1.0
# 2022-10-31  61.6277    0.0983              0              0       -1.0

# %% [markdown]
# ### Масштабирование данных
# ---
# - перед применение нейросети необходимо отмасштабировать данные. Это можно сделать сразу или строить pipline непосредственно при обучении/применении нейросети.
#
# - шкалер нам может понадобиться для того, чтобы дешкалировать данные для последующего анализа.

# %%
df.describe()
# Out:
#             dollar     d_dollar  day_of_week_5  day_of_week_6     sin_month
# count  5052.000000  5052.000000    5052.000000    5052.000000  5.052000e+03
# mean     51.370161     0.006381       0.142914       0.142914  4.993958e-03
# std      18.079718     0.650414       0.350019       0.350019  7.070891e-01
# min      27.262500    -8.182200       0.000000       0.000000 -1.000000e+00
# 25%      31.568700    -0.094100       0.000000       0.000000 -5.000000e-01
# 50%      57.558500     0.000000       0.000000       0.000000  1.224647e-16
# 75%      65.666950     0.085050       0.000000       0.000000  8.660254e-01
# max     118.438900    16.569800       1.000000       1.000000  1.000000e+00

# %% [markdown]
# Воспользуемся стандартным шкалером для масштабирования самого курса и его колебаний;
#
# - нужно указать какие из признаков мы будем кодировать features_to_scale; в нашем случае набор признаков совпадает с целевыми признаками
#
# - шкалирование производим по обучающей выборке

# %%
from sklearn.preprocessing import StandardScaler

dollar_scaler = StandardScaler()
features_to_scale = goal_features
dollar_scaler.fit(df.loc[train_cond, features_to_scale])

df_norm = df.copy()
df_norm.loc[:, features_to_scale] = dollar_scaler.transform(df.loc[:, features_to_scale])
df_norm.describe()
# Out:
#             dollar     d_dollar  day_of_week_5  day_of_week_6     sin_month
# count  5052.000000  5052.000000    5052.000000    5052.000000  5.052000e+03
# mean     -0.978557    -0.013103       0.142914       0.142914  4.993958e-03
# std       1.624655     1.082214       0.350019       0.350019  7.070891e-01
# min      -3.144887   -13.637959       0.000000       0.000000 -1.000000e+00
# 25%      -2.757929    -0.180292       0.000000       0.000000 -5.000000e-01
# 50%      -0.422468    -0.023720       0.000000       0.000000  1.224647e-16
# 75%       0.306162     0.117793       0.000000       0.000000  8.660254e-01
# max       5.048285    27.546520       1.000000       1.000000  1.000000e+00

# %% [markdown]
# ## **Готовим датасеты**
# ---
# - Выбираем ширину окна win_width и шаг по окну win_step;
# - формируем свой класс датасета;
# - готовим datasets для обучения и для тестирования

# %%
import tensorflow as tf

# %% [markdown]
# ### Класс WindowGenerator
#
# Мы сконструируем класс WindowGenerator, в котором будет реализован метод `make_dataset` на вход которого подается a time series DataFrame и ковертируется в `tf.data.Dataset`, состоящий из пар формы `(input_window, label_window)` с использованием функции `tf.keras.utils.timeseries_dataset_from_array`.
#
# Для генерации пар временных окон будут использоваться следующие параметры:
#
# - input_width - это ширина входного окна;
# - label_width - ширина выходного (прогнозируемого или восстанавливаемого) окна;
# - shift - сдвиг индекса конца выходного окна от индекса конца входного окна;
# - label_columns - если надо прогнозировать/восстанавливать только часть имеющихся в df признаков; если None, то надо все признаки восстанавливать.
#
# Для задачи восстановления/эмбеддинга берем:
#
# * input_width = label_width = win_width
# * shift = 0
#
# для прогнозирования вперед на predict_width:
# * shift = predict_width
#
# при этом могут быть варианты:
# * label_width = shift
# * label_width > shift  (для авторегрессионных моделей с частичным "teacher_forcing")

# %%
class WindowGenerator():
    def __init__(self, input_width, label_width, shift, stride=1,
                 batch_size=1, df=df_norm, label_columns=None):
        # Store the raw data.
        self.df = df
        self.input_size = input_width
        self.batch_size = batch_size
        self.stride = stride

        # Work out the label column indices.
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(df.columns)}

        # Work out the window parameters.
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    def __repr__(self):
        return '\n'.join([
            f'Total window size: {self.total_window_size}',
            f'Input indices: {self.input_indices}',
            f'Label indices: {self.label_indices}',
            f'Label column name(s): {self.label_columns}'])
    
    def split_window(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:, :, self.column_indices[name]] for name in self.label_columns],
                axis=-1)
        # Slicing doesn't preserve static shape information, so set the shapes
        # manually. This way the `tf.data.Datasets` are easier to inspect.
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])

        return inputs, labels

    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.utils.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=self.stride,
            shuffle=True,
            batch_size=self.batch_size,
            )
        
        ds = ds.map(self.split_window)
        return ds

    @property
    def dataset(self):
        return self.make_dataset(self.df)

    @property
    def example(self):
        """Get and cache an example batch of `inputs, labels` for plotting."""
        result = getattr(self, '_example', None)
        if result is None:
            result = next(iter(self.dataset))
            # And cache it for next time
            self._example = result
        return result

# %% [markdown]
# ### Выбираем ширину окна win_width, формируем датасет последовательностей
# ---
# данный класс можно будет использовать:
# - для разделения на обучющий (до определенной даты) и тестовый (после определенной даты);
# - для оценки точности алгоритма кодирования на всей выборке;

# %%
# ширина окна (должна быть нечетная)
win_width = 31
win_step = 1

all_data = WindowGenerator(
    input_width= win_width,
    label_width= win_width,
    shift= 0,
    df = df_norm,
    stride= win_step,
    label_columns= goal_features
    )

all_data.dataset.element_spec
# Out:
# (TensorSpec(shape=(None, 31, 5), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 31, 2), dtype=tf.float32, name=None))

# %%
for example_inputs, example_labels in all_data.dataset.take(2):
    print(f'Inputs shape (batch, time, features): {example_inputs.shape}')
    print(f'Labels shape (batch, time, features): {example_labels.shape}')
# Out:
# Inputs shape (batch, time, features): (1, 31, 5)
# Labels shape (batch, time, features): (1, 31, 2)
# Inputs shape (batch, time, features): (1, 31, 5)
# Labels shape (batch, time, features): (1, 31, 2)

# %%
count = 0
for example_inputs, example_labels in all_data.dataset:
    count += 1

print(count)
# Out:
# 5022

# %% [markdown]
# ### Формируем выборки для обучения и тестирования и соответствующие датасеты
# ---
# Применяем два этапа разбиения.
# - Этап 1. Выбираем дату, разделяющую всю последовательность на две части - обучающую и тестовую; это полезно для обучения прогнозированию и выявления аномалий.
#
# - Этап 2. Из всех последовательностей выбираем случайно определенный % для обучающей выборки; остальные - в выборку для валидизации.

# %% [markdown]
# Сгенерируем датасеты для обучающей, валидизирующей и тестовой выборки

# %%
# шаги, с которым будем формировать данные выборки
win_step = 1
batch_size = 32

train_ds = WindowGenerator(
    input_width = win_width,
    label_width = win_width,
    shift = 0,
    df = df_norm[train_cond],
    stride = win_step,
    batch_size = batch_size,
    label_columns = goal_features
    ).dataset

test_ds = WindowGenerator(
    input_width = win_width,
    label_width = win_width,
    shift = 0,
    df = df_norm[test_cond],
    stride = win_step,
    batch_size = batch_size,
    label_columns = goal_features
    ).dataset

# %%
train_ds = train_ds.unbatch().batch(batch_size, drop_remainder=True)
test_ds = test_ds.unbatch().batch(batch_size, drop_remainder=True)

# %%
for example_inputs, example_labels in train_ds.take(2):
    print(f'Inputs shape (batch, time, features): {example_inputs.shape}')
    # print(f'Labels shape (batch, time, features): {example_labels.shape}')
# Out:
# Inputs shape (batch, time, features): (32, 31, 5)
# Inputs shape (batch, time, features): (32, 31, 5)

# %%
batch_seq, label_seq = next(iter(train_ds))
print(batch_seq.shape, label_seq.shape)
# Out:
# (32, 31, 5) (32, 31, 2)

# %% [markdown]
# - чтобы не было проблем с загрузкой данных на девайс, лучше использовать обвертку для даталоадеров WrappedDataLoader
#
# - При подготовке пакета для обучения/тестирования из даталоадера
# выдается тензор вида (batch_size, seq_len, features); для nn.Conv1d необходимо менять местами индексы seq_len, feature, т.е. должен на вход поступать тензор вида (batch_size, features, seq_len); мы это сделаем также в функции preprocess

# %%
tf.transpose(batch_seq, perm=(0, 2, 1)).shape
# Out:
# TensorShape([32, 5, 31])

# %%
"""
# это заготовка для RNN

def preprocess(x, y):
    # x, y = xy
    x = tf.transpose(x, perm=(0, 2, 1))
    y = tf.transpose(y, perm=(0, 2, 1))
    return x, y


def WrappedDataset(ds):
    prep_ds = ds.map(preprocess)
    return prep_ds

train_ds.map(preprocess).element_spec

train_ds = WrappedDataset(train_ds)

batch_seq, label_seq = next(iter(train_ds))
print(batch_seq.shape, label_seq.shape)
"""
# Out:
# '\n# это заготовка для RNN\n\ndef preprocess(x, y):\n    # x, y = xy\n    x = tf.transpose(x, perm=(0, 2, 1))\n    y = tf.transpose(y, perm=(0, 2, 1))\n    return x, y\n\n\ndef WrappedDataset(ds):\n    prep_ds = ds.map(preprocess)\n    return prep_ds\n\ntrain_ds.map(preprocess).element_spec\n\ntrain_ds = WrappedDataset(train_ds)\n\nbatch_seq, label_seq = next(iter(train_ds))\nprint(batch_seq.shape, label_seq.shape)\n'

# %% [markdown]
# ## **Строим АЭ с выделением энкодера в отдельную нейросеть**
# ---
# Создадим простой сверточный автоэнкодер который выделяет важные признаки в последовательностях заданной длины заданных векторов фичей.

# %%
# выбираем размерность скрытого слоя и размеры ядер свертки
latent_dim = 64
n_features = len(features)
n_labels = len(goal_features)
dropout = 0.2

# %% [markdown]
# ### LSTM-Энкодер (Кодировщик последовательностей)
# ---

# %%
encoder = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, latent_dim]
    tf.keras.layers.LSTM(latent_dim, return_sequences=True, dropout=dropout),
    # Shape [batch, time, features] => [batch, latent_dim]
    tf.keras.layers.LSTM(latent_dim, return_sequences=False, dropout=dropout),
])

batch_seq, _ = next(iter(train_ds))
print(batch_seq.shape, encoder(batch_seq).shape)
encoder.summary()
# Out:
# (32, 31, 5) (32, 64)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (32, 31, 64)              17920
#
#  lstm_5 (LSTM)               (32, 64)                  33024
#
# =================================================================
# Total params: 50,944
# Trainable params: 50,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
code = encoder(batch_seq)
batch_seq.shape, code.shape
# Out:
# (TensorShape([32, 31, 5]), TensorShape([32, 64]))

# %% [markdown]
# ### LSTM-Декодер (Генератор последовательностей). Авторегрессионная модель.
# ---

# %%
class FeedBack(tf.keras.Model):
    def __init__(self, latent_dim, win_width, n_features):
        super().__init__()
        self.out_steps = win_width
        self.units = latent_dim
        self.n_features = n_features
        self.lstm_cell = tf.keras.layers.LSTMCell(latent_dim)
        # Also wrap the LSTMCell in an RNN to simplify the `warmup` method.
        self.lstm_rnn = tf.keras.layers.RNN(self.lstm_cell, return_state=True)
        self.dense = tf.keras.layers.Dense(n_features)

# %% [markdown]
# The first method this model needs is a warmup method to initialize its internal state based on the inputs. Once trained, this state will capture the relevant parts of the input history. This is equivalent to the single-step LSTM model from earlier:

# %%
def warmup(self, x):
    # x.shape => (batch, lstm_units)
    state_h = x
    state_c = tf.zeros_like(state_h)
    if x.shape[0]:
        init_inputs = tf.zeros((x.shape[0], 1, self.n_features)) 
    else:
        init_inputs = tf.zeros((batch_size, 1, self.n_features)) 
    
    state = [state_h, state_c]
    
    # x.shape => (batch, lstm_units)
    x, *state = self.lstm_rnn(init_inputs, initial_state=state)

    # predictions.shape => (batch, features)
    prediction = self.dense(x)
    return prediction, state

FeedBack.warmup = warmup

# %% [markdown]
# With the RNN's state, and an initial prediction you can now continue iterating the model feeding the predictions at each step back as the input.
#
# The simplest approach for collecting the output predictions is to use a Python list and a tf.stack after the loop.
#
# Note: Stacking a Python list like this only works with eager-execution, using Model.compile(..., run_eagerly=True) for training, or with a fixed length output. For a dynamic output length, you would need to use a tf.TensorArray instead of a Python list, and tf.range instead of the Python range.

# %%
def call(self, input_hidden, training=None):
    # Use a TensorArray to capture dynamically unrolled outputs.
    predictions = []
    # Initialize the LSTM state.
    prediction, state = self.warmup(input_hidden)

    # Insert the first prediction.
    predictions.append(prediction)

    # Run the rest of the prediction steps.
    for n in range(1, self.out_steps):
        # Use the last prediction as input.
        x = prediction
        # Execute one lstm step.
        x, state = self.lstm_cell(x, states=state, training=training)
        # Convert the lstm output to a prediction.
        prediction = self.dense(x)
        # Add the prediction to the output.
        predictions.append(prediction)

    # predictions.shape => (time, batch, features)
    predictions = tf.stack(predictions)
    # predictions.shape => (batch, time, features)
    predictions = tf.transpose(predictions, [1, 0, 2])
    return predictions

FeedBack.call = call

# %%
decoder = FeedBack(latent_dim=latent_dim, win_width=win_width, n_features=n_labels)

print('Output shape (batch, time, features): ', decoder(code).shape)

print(code.shape, decoder(code).shape)
decoder.summary()
# Out:
# Output shape (batch, time, features):  (32, 31, 2)
# (32, 64) (32, 31, 2)
# Model: "feed_back_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_cell_21 (LSTMCell)     multiple                  17152
#
#  rnn_15 (RNN)                multiple                  17152
#
#  dense_15 (Dense)            multiple                  130
#
# =================================================================
# Total params: 17,282
# Trainable params: 17,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
decode = decoder(code)
code.shape, decode.shape
# Out:
# (TensorShape([32, 64]), TensorShape([32, 31, 2]))

# %% [markdown]
# ### Автоэнкодер
# ---

# %%
def CNN_ae(encoder, decoder):
    input_seq = tf.keras.layers.Input(shape=(win_width, n_features))
    code = encoder(input_seq)
    output_seq = decoder(code)
    autoencoder = tf.keras.Model(input_seq, output_seq, name="autoencoder")
    return autoencoder

cnn_ae = CNN_ae(encoder, decoder)

print(cnn_ae(batch_seq).shape)
cnn_ae.summary()
# Out:
# (32, 31, 2)
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 31, 5)]           0
#
#  sequential_2 (Sequential)   (None, 64)                50944
#
#  feed_back_15 (FeedBack)     (32, 31, 2)               17282
#
# =================================================================
# Total params: 68,226
# Trainable params: 68,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
reconstucted_seq = cnn_ae(batch_seq)
reconstucted_seq.shape, batch_seq.shape
# Out:
# (TensorShape([32, 31, 2]), TensorShape([32, 31, 5]))

# %% [markdown]
# ## **Обучаем АЭ**
# ---

# %%
history_c = None

# %%
cnn_ae.compile(optimizer='adam', loss='mean_squared_error', metrics= [tf.keras.metrics.MeanAbsoluteError()])

# %%
from IPython.core import history
history_1 = cnn_ae.fit(train_ds, epochs=200,  shuffle=True, validation_data=test_ds, verbose=1, )
# Out:
# Epoch 1/200
# 90/90 [==============================] - 6s 62ms/step - loss: 0.4022 - mean_absolute_error: 0.2908 - val_loss: 5.0139 - val_mean_absolute_error: 0.9391
# Epoch 2/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.4096 - mean_absolute_error: 0.2914 - val_loss: 5.0201 - val_mean_absolute_error: 0.9286
# Epoch 3/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.4090 - mean_absolute_error: 0.2922 - val_loss: 4.6798 - val_mean_absolute_error: 0.8974
# Epoch 4/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.4047 - mean_absolute_error: 0.2887 - val_loss: 5.0063 - val_mean_absolute_error: 0.9345
# Epoch 5/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.4103 - mean_absolute_error: 0.2909 - val_loss: 4.8241 - val_mean_absolute_error: 0.9106
# Epoch 6/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.4097 - mean_absolute_error: 0.2898 - val_loss: 4.7767 - val_mean_absolute_error: 0.8997
# Epoch 7/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.4020 - mean_absolute_error: 0.2887 - val_loss: 4.7140 - val_mean_absolute_error: 0.8881
# Epoch 8/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.4034 - mean_absolute_error: 0.2899 - val_loss: 5.0090 - val_mean_absolute_error: 0.9445
# Epoch 9/200
# 90/90 [==============================] - 7s 72ms/step - loss: 0.4139 - mean_absolute_error: 0.2907 - val_loss: 5.0111 - val_mean_absolute_error: 0.9343
# Epoch 10/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3986 - mean_absolute_error: 0.2881 - val_loss: 4.8956 - val_mean_absolute_error: 0.9244
# Epoch 11/200
# 90/90 [==============================] - 6s 71ms/step - loss: 0.4011 - mean_absolute_error: 0.2906 - val_loss: 5.1249 - val_mean_absolute_error: 0.9447
# Epoch 12/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.4034 - mean_absolute_error: 0.2898 - val_loss: 4.8062 - val_mean_absolute_error: 0.9047
# Epoch 13/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.4028 - mean_absolute_error: 0.2892 - val_loss: 4.7548 - val_mean_absolute_error: 0.9020
# Epoch 14/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3927 - mean_absolute_error: 0.2888 - val_loss: 4.8829 - val_mean_absolute_error: 0.9355
# Epoch 15/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.4054 - mean_absolute_error: 0.2903 - val_loss: 4.8468 - val_mean_absolute_error: 0.9155
# Epoch 16/200
# 90/90 [==============================] - 5s 50ms/step - loss: 0.4059 - mean_absolute_error: 0.2909 - val_loss: 5.1105 - val_mean_absolute_error: 0.9504
# Epoch 17/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.4019 - mean_absolute_error: 0.2880 - val_loss: 4.7933 - val_mean_absolute_error: 0.9104
# Epoch 18/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.4175 - mean_absolute_error: 0.2929 - val_loss: 4.9255 - val_mean_absolute_error: 0.9196
# Epoch 19/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.4170 - mean_absolute_error: 0.2913 - val_loss: 5.2154 - val_mean_absolute_error: 0.9510
# Epoch 20/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3895 - mean_absolute_error: 0.2884 - val_loss: 4.8758 - val_mean_absolute_error: 0.9254
# Epoch 21/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3971 - mean_absolute_error: 0.2893 - val_loss: 4.9346 - val_mean_absolute_error: 0.9279
# Epoch 22/200
# 90/90 [==============================] - 6s 70ms/step - loss: 0.4005 - mean_absolute_error: 0.2890 - val_loss: 5.1467 - val_mean_absolute_error: 0.9475
# Epoch 23/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.4053 - mean_absolute_error: 0.2909 - val_loss: 5.0627 - val_mean_absolute_error: 0.9182
# Epoch 24/200
# 90/90 [==============================] - 6s 71ms/step - loss: 0.4043 - mean_absolute_error: 0.2909 - val_loss: 5.0368 - val_mean_absolute_error: 0.9329
# Epoch 25/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.4204 - mean_absolute_error: 0.2919 - val_loss: 4.8158 - val_mean_absolute_error: 0.9094
# Epoch 26/200
# 90/90 [==============================] - 6s 67ms/step - loss: 0.3921 - mean_absolute_error: 0.2860 - val_loss: 4.9028 - val_mean_absolute_error: 0.9257
# Epoch 27/200
# 90/90 [==============================] - 6s 62ms/step - loss: 0.3953 - mean_absolute_error: 0.2876 - val_loss: 4.9323 - val_mean_absolute_error: 0.9225
# Epoch 28/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3953 - mean_absolute_error: 0.2880 - val_loss: 4.9223 - val_mean_absolute_error: 0.9194
# Epoch 29/200
# 90/90 [==============================] - 6s 72ms/step - loss: 0.3943 - mean_absolute_error: 0.2871 - val_loss: 4.7603 - val_mean_absolute_error: 0.8915
# Epoch 30/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3867 - mean_absolute_error: 0.2871 - val_loss: 5.2904 - val_mean_absolute_error: 0.9607
# Epoch 31/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3842 - mean_absolute_error: 0.2889 - val_loss: 5.1579 - val_mean_absolute_error: 0.9479
# Epoch 32/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3962 - mean_absolute_error: 0.2876 - val_loss: 5.1044 - val_mean_absolute_error: 0.9402
# Epoch 33/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3956 - mean_absolute_error: 0.2882 - val_loss: 4.8918 - val_mean_absolute_error: 0.9070
# Epoch 34/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3834 - mean_absolute_error: 0.2848 - val_loss: 5.0102 - val_mean_absolute_error: 0.9293
# Epoch 35/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3850 - mean_absolute_error: 0.2854 - val_loss: 4.8403 - val_mean_absolute_error: 0.9212
# Epoch 36/200
# 90/90 [==============================] - 5s 58ms/step - loss: 0.3801 - mean_absolute_error: 0.2856 - val_loss: 4.7841 - val_mean_absolute_error: 0.9108
# Epoch 37/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3804 - mean_absolute_error: 0.2839 - val_loss: 5.0044 - val_mean_absolute_error: 0.9437
# Epoch 38/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3860 - mean_absolute_error: 0.2844 - val_loss: 4.8460 - val_mean_absolute_error: 0.9094
# Epoch 39/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.4035 - mean_absolute_error: 0.2880 - val_loss: 4.9871 - val_mean_absolute_error: 0.9278
# Epoch 40/200
# 90/90 [==============================] - 7s 72ms/step - loss: 0.3846 - mean_absolute_error: 0.2872 - val_loss: 5.0605 - val_mean_absolute_error: 0.9341
# Epoch 41/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3969 - mean_absolute_error: 0.2862 - val_loss: 5.1656 - val_mean_absolute_error: 0.9337
# Epoch 42/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3778 - mean_absolute_error: 0.2833 - val_loss: 4.6752 - val_mean_absolute_error: 0.8992
# Epoch 43/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3779 - mean_absolute_error: 0.2847 - val_loss: 4.8261 - val_mean_absolute_error: 0.9152
# Epoch 44/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3903 - mean_absolute_error: 0.2873 - val_loss: 4.9575 - val_mean_absolute_error: 0.9280
# Epoch 45/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3945 - mean_absolute_error: 0.2851 - val_loss: 5.0914 - val_mean_absolute_error: 0.9369
# Epoch 46/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3858 - mean_absolute_error: 0.2845 - val_loss: 4.9447 - val_mean_absolute_error: 0.9260
# Epoch 47/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3886 - mean_absolute_error: 0.2864 - val_loss: 4.9486 - val_mean_absolute_error: 0.9226
# Epoch 48/200
# 90/90 [==============================] - 5s 58ms/step - loss: 0.3928 - mean_absolute_error: 0.2863 - val_loss: 4.6668 - val_mean_absolute_error: 0.9001
# Epoch 49/200
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3839 - mean_absolute_error: 0.2849 - val_loss: 4.9673 - val_mean_absolute_error: 0.9231
# Epoch 50/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3725 - mean_absolute_error: 0.2835 - val_loss: 4.9365 - val_mean_absolute_error: 0.9280
# Epoch 51/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3643 - mean_absolute_error: 0.2810 - val_loss: 4.9037 - val_mean_absolute_error: 0.9163
# Epoch 52/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3796 - mean_absolute_error: 0.2834 - val_loss: 4.7855 - val_mean_absolute_error: 0.9033
# Epoch 53/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3712 - mean_absolute_error: 0.2828 - val_loss: 4.8881 - val_mean_absolute_error: 0.9216
# Epoch 54/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3860 - mean_absolute_error: 0.2883 - val_loss: 5.1088 - val_mean_absolute_error: 0.9354
# Epoch 55/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.4053 - mean_absolute_error: 0.2899 - val_loss: 5.1394 - val_mean_absolute_error: 0.9336
# Epoch 56/200
# 90/90 [==============================] - 7s 72ms/step - loss: 0.4024 - mean_absolute_error: 0.2904 - val_loss: 4.9292 - val_mean_absolute_error: 0.9185
# Epoch 57/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3734 - mean_absolute_error: 0.2848 - val_loss: 5.0424 - val_mean_absolute_error: 0.9421
# Epoch 58/200
# 90/90 [==============================] - 6s 69ms/step - loss: 0.3784 - mean_absolute_error: 0.2844 - val_loss: 4.9601 - val_mean_absolute_error: 0.9264
# Epoch 59/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3845 - mean_absolute_error: 0.2866 - val_loss: 5.1075 - val_mean_absolute_error: 0.9357
# Epoch 60/200
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3732 - mean_absolute_error: 0.2851 - val_loss: 5.2332 - val_mean_absolute_error: 0.9560
# Epoch 61/200
# 90/90 [==============================] - 5s 58ms/step - loss: 0.3825 - mean_absolute_error: 0.2849 - val_loss: 5.1732 - val_mean_absolute_error: 0.9530
# Epoch 62/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3989 - mean_absolute_error: 0.2886 - val_loss: 5.2097 - val_mean_absolute_error: 0.9493
# Epoch 63/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3846 - mean_absolute_error: 0.2875 - val_loss: 5.0383 - val_mean_absolute_error: 0.9265
# Epoch 64/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.3588 - mean_absolute_error: 0.2825 - val_loss: 5.1225 - val_mean_absolute_error: 0.9399
# Epoch 65/200
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3567 - mean_absolute_error: 0.2811 - val_loss: 4.8878 - val_mean_absolute_error: 0.9187
# Epoch 66/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3650 - mean_absolute_error: 0.2826 - val_loss: 5.0548 - val_mean_absolute_error: 0.9340
# Epoch 67/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.3873 - mean_absolute_error: 0.2847 - val_loss: 5.2103 - val_mean_absolute_error: 0.9514
# Epoch 68/200
# 90/90 [==============================] - 6s 68ms/step - loss: 0.3725 - mean_absolute_error: 0.2834 - val_loss: 4.6458 - val_mean_absolute_error: 0.8985
# Epoch 69/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3678 - mean_absolute_error: 0.2817 - val_loss: 4.8227 - val_mean_absolute_error: 0.9057
# Epoch 70/200
# 90/90 [==============================] - 6s 68ms/step - loss: 0.3674 - mean_absolute_error: 0.2816 - val_loss: 5.0877 - val_mean_absolute_error: 0.9528
# Epoch 71/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.3611 - mean_absolute_error: 0.2798 - val_loss: 4.9714 - val_mean_absolute_error: 0.9304
# Epoch 72/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3764 - mean_absolute_error: 0.2862 - val_loss: 5.1192 - val_mean_absolute_error: 0.9378
# Epoch 73/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3719 - mean_absolute_error: 0.2845 - val_loss: 5.1455 - val_mean_absolute_error: 0.9485
# Epoch 74/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3719 - mean_absolute_error: 0.2830 - val_loss: 5.0591 - val_mean_absolute_error: 0.9352
# Epoch 75/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3810 - mean_absolute_error: 0.2837 - val_loss: 4.9416 - val_mean_absolute_error: 0.9188
# Epoch 76/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3568 - mean_absolute_error: 0.2810 - val_loss: 5.0573 - val_mean_absolute_error: 0.9336
# Epoch 77/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3586 - mean_absolute_error: 0.2798 - val_loss: 5.0437 - val_mean_absolute_error: 0.9391
# Epoch 78/200
# 90/90 [==============================] - 5s 61ms/step - loss: 0.3643 - mean_absolute_error: 0.2802 - val_loss: 5.0673 - val_mean_absolute_error: 0.9398
# Epoch 79/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3572 - mean_absolute_error: 0.2827 - val_loss: 5.0475 - val_mean_absolute_error: 0.9273
# Epoch 80/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3498 - mean_absolute_error: 0.2775 - val_loss: 5.2546 - val_mean_absolute_error: 0.9636
# Epoch 81/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3550 - mean_absolute_error: 0.2784 - val_loss: 4.9524 - val_mean_absolute_error: 0.9200
# Epoch 82/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3758 - mean_absolute_error: 0.2850 - val_loss: 4.9770 - val_mean_absolute_error: 0.9300
# Epoch 83/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3764 - mean_absolute_error: 0.2838 - val_loss: 5.1453 - val_mean_absolute_error: 0.9446
# Epoch 84/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3454 - mean_absolute_error: 0.2775 - val_loss: 5.1984 - val_mean_absolute_error: 0.9583
# Epoch 85/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3622 - mean_absolute_error: 0.2833 - val_loss: 5.0382 - val_mean_absolute_error: 0.9196
# Epoch 86/200
# 90/90 [==============================] - 5s 51ms/step - loss: 0.3433 - mean_absolute_error: 0.2797 - val_loss: 5.3638 - val_mean_absolute_error: 0.9686
# Epoch 87/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3768 - mean_absolute_error: 0.2841 - val_loss: 4.7907 - val_mean_absolute_error: 0.9252
# Epoch 88/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3469 - mean_absolute_error: 0.2772 - val_loss: 5.0107 - val_mean_absolute_error: 0.9300
# Epoch 89/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3522 - mean_absolute_error: 0.2791 - val_loss: 5.1469 - val_mean_absolute_error: 0.9448
# Epoch 90/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3472 - mean_absolute_error: 0.2772 - val_loss: 4.8580 - val_mean_absolute_error: 0.9143
# Epoch 91/200
# 90/90 [==============================] - 7s 72ms/step - loss: 0.3756 - mean_absolute_error: 0.2840 - val_loss: 5.1800 - val_mean_absolute_error: 0.9479
# Epoch 92/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3630 - mean_absolute_error: 0.2835 - val_loss: 4.9947 - val_mean_absolute_error: 0.9317
# Epoch 93/200
# 90/90 [==============================] - 6s 62ms/step - loss: 0.3602 - mean_absolute_error: 0.2815 - val_loss: 5.3421 - val_mean_absolute_error: 0.9713
# Epoch 94/200
# 90/90 [==============================] - 6s 60ms/step - loss: 0.3514 - mean_absolute_error: 0.2802 - val_loss: 5.1076 - val_mean_absolute_error: 0.9396
# Epoch 95/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3557 - mean_absolute_error: 0.2791 - val_loss: 5.2752 - val_mean_absolute_error: 0.9624
# Epoch 96/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3475 - mean_absolute_error: 0.2771 - val_loss: 5.0288 - val_mean_absolute_error: 0.9273
# Epoch 97/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3428 - mean_absolute_error: 0.2763 - val_loss: 5.0740 - val_mean_absolute_error: 0.9339
# Epoch 98/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3526 - mean_absolute_error: 0.2801 - val_loss: 4.6245 - val_mean_absolute_error: 0.8972
# Epoch 99/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3450 - mean_absolute_error: 0.2799 - val_loss: 4.8211 - val_mean_absolute_error: 0.9134
# Epoch 100/200
# 90/90 [==============================] - 5s 57ms/step - loss: 0.3463 - mean_absolute_error: 0.2777 - val_loss: 4.8641 - val_mean_absolute_error: 0.9191
# Epoch 101/200
# 90/90 [==============================] - 6s 70ms/step - loss: 0.3535 - mean_absolute_error: 0.2813 - val_loss: 4.8460 - val_mean_absolute_error: 0.9160
# Epoch 102/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3444 - mean_absolute_error: 0.2793 - val_loss: 5.0864 - val_mean_absolute_error: 0.9316
# Epoch 103/200
# 90/90 [==============================] - 6s 68ms/step - loss: 0.3592 - mean_absolute_error: 0.2795 - val_loss: 4.9163 - val_mean_absolute_error: 0.9057
# Epoch 104/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3193 - mean_absolute_error: 0.2730 - val_loss: 5.0100 - val_mean_absolute_error: 0.9309
# Epoch 105/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3852 - mean_absolute_error: 0.2842 - val_loss: 5.2878 - val_mean_absolute_error: 0.9535
# Epoch 106/200
# 90/90 [==============================] - 5s 52ms/step - loss: 0.3486 - mean_absolute_error: 0.2789 - val_loss: 5.0358 - val_mean_absolute_error: 0.9313
# Epoch 107/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3843 - mean_absolute_error: 0.2887 - val_loss: 5.0298 - val_mean_absolute_error: 0.9470
# Epoch 108/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3612 - mean_absolute_error: 0.2855 - val_loss: 5.3530 - val_mean_absolute_error: 0.9648
# Epoch 109/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3481 - mean_absolute_error: 0.2792 - val_loss: 4.8064 - val_mean_absolute_error: 0.9104
# Epoch 110/200
# 90/90 [==============================] - 6s 71ms/step - loss: 0.3382 - mean_absolute_error: 0.2770 - val_loss: 5.1435 - val_mean_absolute_error: 0.9530
# Epoch 111/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3379 - mean_absolute_error: 0.2762 - val_loss: 5.1263 - val_mean_absolute_error: 0.9497
# Epoch 112/200
# 90/90 [==============================] - 6s 65ms/step - loss: 0.3411 - mean_absolute_error: 0.2762 - val_loss: 5.0317 - val_mean_absolute_error: 0.9291
# Epoch 113/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3304 - mean_absolute_error: 0.2743 - val_loss: 5.0739 - val_mean_absolute_error: 0.9258
# Epoch 114/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3125 - mean_absolute_error: 0.2718 - val_loss: 5.0777 - val_mean_absolute_error: 0.9320
# Epoch 115/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3326 - mean_absolute_error: 0.2745 - val_loss: 5.1774 - val_mean_absolute_error: 0.9385
# Epoch 116/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3378 - mean_absolute_error: 0.2756 - val_loss: 5.1014 - val_mean_absolute_error: 0.9264
# Epoch 117/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3289 - mean_absolute_error: 0.2739 - val_loss: 5.2601 - val_mean_absolute_error: 0.9431
# Epoch 118/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3368 - mean_absolute_error: 0.2766 - val_loss: 5.1897 - val_mean_absolute_error: 0.9405
# Epoch 119/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3459 - mean_absolute_error: 0.2792 - val_loss: 4.9960 - val_mean_absolute_error: 0.9291
# Epoch 120/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3487 - mean_absolute_error: 0.2783 - val_loss: 5.1754 - val_mean_absolute_error: 0.9379
# Epoch 121/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3200 - mean_absolute_error: 0.2733 - val_loss: 5.1584 - val_mean_absolute_error: 0.9296
# Epoch 122/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3120 - mean_absolute_error: 0.2701 - val_loss: 4.9014 - val_mean_absolute_error: 0.9258
# Epoch 123/200
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3622 - mean_absolute_error: 0.2805 - val_loss: 4.8505 - val_mean_absolute_error: 0.9088
# Epoch 124/200
# 90/90 [==============================] - 5s 57ms/step - loss: 0.3610 - mean_absolute_error: 0.2801 - val_loss: 4.9174 - val_mean_absolute_error: 0.9047
# Epoch 125/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3296 - mean_absolute_error: 0.2734 - val_loss: 5.0843 - val_mean_absolute_error: 0.9306
# Epoch 126/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3303 - mean_absolute_error: 0.2761 - val_loss: 5.0898 - val_mean_absolute_error: 0.9209
# Epoch 127/200
# 90/90 [==============================] - 5s 58ms/step - loss: 0.3330 - mean_absolute_error: 0.2745 - val_loss: 5.2451 - val_mean_absolute_error: 0.9351
# Epoch 128/200
# 90/90 [==============================] - 7s 72ms/step - loss: 0.3252 - mean_absolute_error: 0.2711 - val_loss: 5.4020 - val_mean_absolute_error: 0.9532
# Epoch 129/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3122 - mean_absolute_error: 0.2705 - val_loss: 4.9662 - val_mean_absolute_error: 0.9197
# Epoch 130/200
# 90/90 [==============================] - 6s 67ms/step - loss: 0.3344 - mean_absolute_error: 0.2729 - val_loss: 5.0213 - val_mean_absolute_error: 0.9438
# Epoch 131/200
# 90/90 [==============================] - 6s 61ms/step - loss: 0.3297 - mean_absolute_error: 0.2755 - val_loss: 5.0353 - val_mean_absolute_error: 0.9334
# Epoch 132/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3251 - mean_absolute_error: 0.2745 - val_loss: 5.2077 - val_mean_absolute_error: 0.9593
# Epoch 133/200
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3105 - mean_absolute_error: 0.2724 - val_loss: 5.1893 - val_mean_absolute_error: 0.9499
# Epoch 134/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3033 - mean_absolute_error: 0.2696 - val_loss: 4.9734 - val_mean_absolute_error: 0.9207
# Epoch 135/200
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3357 - mean_absolute_error: 0.2749 - val_loss: 4.9955 - val_mean_absolute_error: 0.9261
# Epoch 136/200
# 90/90 [==============================] - 6s 71ms/step - loss: 0.3409 - mean_absolute_error: 0.2765 - val_loss: 5.1132 - val_mean_absolute_error: 0.9421
# Epoch 137/200
# 90/90 [==============================] - 6s 61ms/step - loss: 0.3287 - mean_absolute_error: 0.2755 - val_loss: 5.4988 - val_mean_absolute_error: 0.9650
# Epoch 138/200
# 90/90 [==============================] - 6s 68ms/step - loss: 0.3729 - mean_absolute_error: 0.2830 - val_loss: 5.1662 - val_mean_absolute_error: 0.9478
# Epoch 139/200
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3371 - mean_absolute_error: 0.2740 - val_loss: 4.8511 - val_mean_absolute_error: 0.9167
# Epoch 140/200
# 90/90 [==============================] - 6s 65ms/step - loss: 0.3217 - mean_absolute_error: 0.2728 - val_loss: 4.7512 - val_mean_absolute_error: 0.9010
# Epoch 141/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3421 - mean_absolute_error: 0.2739 - val_loss: 5.1242 - val_mean_absolute_error: 0.9353
# Epoch 142/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3264 - mean_absolute_error: 0.2720 - val_loss: 5.1714 - val_mean_absolute_error: 0.9492
# Epoch 143/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3115 - mean_absolute_error: 0.2730 - val_loss: 5.2835 - val_mean_absolute_error: 0.9589
# Epoch 144/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3159 - mean_absolute_error: 0.2712 - val_loss: 5.0560 - val_mean_absolute_error: 0.9317
# Epoch 145/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3392 - mean_absolute_error: 0.2734 - val_loss: 5.3402 - val_mean_absolute_error: 0.9536
# Epoch 146/200
# 90/90 [==============================] - 6s 62ms/step - loss: 0.3094 - mean_absolute_error: 0.2699 - val_loss: 5.2601 - val_mean_absolute_error: 0.9525
# Epoch 147/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3006 - mean_absolute_error: 0.2674 - val_loss: 5.3153 - val_mean_absolute_error: 0.9578
# Epoch 148/200
# 90/90 [==============================] - 6s 72ms/step - loss: 0.2983 - mean_absolute_error: 0.2673 - val_loss: 5.2430 - val_mean_absolute_error: 0.9423
# Epoch 149/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3420 - mean_absolute_error: 0.2770 - val_loss: 5.2164 - val_mean_absolute_error: 0.9396
# Epoch 150/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3389 - mean_absolute_error: 0.2749 - val_loss: 5.0646 - val_mean_absolute_error: 0.9357
# Epoch 151/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3598 - mean_absolute_error: 0.2794 - val_loss: 5.2349 - val_mean_absolute_error: 0.9492
# Epoch 152/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3454 - mean_absolute_error: 0.2785 - val_loss: 5.1191 - val_mean_absolute_error: 0.9608
# Epoch 153/200
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3595 - mean_absolute_error: 0.2787 - val_loss: 5.1058 - val_mean_absolute_error: 0.9336
# Epoch 154/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3333 - mean_absolute_error: 0.2737 - val_loss: 4.9154 - val_mean_absolute_error: 0.9176
# Epoch 155/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.2983 - mean_absolute_error: 0.2676 - val_loss: 5.1646 - val_mean_absolute_error: 0.9544
# Epoch 156/200
# 90/90 [==============================] - 5s 57ms/step - loss: 0.3107 - mean_absolute_error: 0.2700 - val_loss: 5.0141 - val_mean_absolute_error: 0.9298
# Epoch 157/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3089 - mean_absolute_error: 0.2698 - val_loss: 5.2982 - val_mean_absolute_error: 0.9449
# Epoch 158/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3533 - mean_absolute_error: 0.2787 - val_loss: 5.0535 - val_mean_absolute_error: 0.9060
# Epoch 159/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.3548 - mean_absolute_error: 0.2772 - val_loss: 5.2264 - val_mean_absolute_error: 0.9206
# Epoch 160/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3350 - mean_absolute_error: 0.2759 - val_loss: 5.3976 - val_mean_absolute_error: 0.9538
# Epoch 161/200
# 90/90 [==============================] - 7s 73ms/step - loss: 0.3493 - mean_absolute_error: 0.2754 - val_loss: 5.2427 - val_mean_absolute_error: 0.9376
# Epoch 162/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3104 - mean_absolute_error: 0.2691 - val_loss: 5.2421 - val_mean_absolute_error: 0.9425
# Epoch 163/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.2805 - mean_absolute_error: 0.2629 - val_loss: 5.2802 - val_mean_absolute_error: 0.9446
# Epoch 164/200
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2865 - mean_absolute_error: 0.2665 - val_loss: 5.3116 - val_mean_absolute_error: 0.9478
# Epoch 165/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3079 - mean_absolute_error: 0.2717 - val_loss: 5.3897 - val_mean_absolute_error: 0.9621
# Epoch 166/200
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3261 - mean_absolute_error: 0.2727 - val_loss: 5.0780 - val_mean_absolute_error: 0.9208
# Epoch 167/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.2898 - mean_absolute_error: 0.2668 - val_loss: 5.4054 - val_mean_absolute_error: 0.9334
# Epoch 168/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3524 - mean_absolute_error: 0.2748 - val_loss: 5.0231 - val_mean_absolute_error: 0.9099
# Epoch 169/200
# 90/90 [==============================] - 5s 53ms/step - loss: 0.3384 - mean_absolute_error: 0.2749 - val_loss: 5.2537 - val_mean_absolute_error: 0.9358
# Epoch 170/200
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3130 - mean_absolute_error: 0.2715 - val_loss: 5.3655 - val_mean_absolute_error: 0.9630
# Epoch 171/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3297 - mean_absolute_error: 0.2750 - val_loss: 5.3829 - val_mean_absolute_error: 0.9685
# Epoch 172/200
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3080 - mean_absolute_error: 0.2695 - val_loss: 4.9484 - val_mean_absolute_error: 0.9172
# Epoch 173/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3184 - mean_absolute_error: 0.2715 - val_loss: 5.0979 - val_mean_absolute_error: 0.9361
# Epoch 174/200
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3395 - mean_absolute_error: 0.2740 - val_loss: 5.1313 - val_mean_absolute_error: 0.9443
# Epoch 175/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3076 - mean_absolute_error: 0.2691 - val_loss: 5.2634 - val_mean_absolute_error: 0.9486
# Epoch 176/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3210 - mean_absolute_error: 0.2709 - val_loss: 5.3781 - val_mean_absolute_error: 0.9435
# Epoch 177/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.2951 - mean_absolute_error: 0.2639 - val_loss: 5.4589 - val_mean_absolute_error: 0.9640
# Epoch 178/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3365 - mean_absolute_error: 0.2786 - val_loss: 5.2661 - val_mean_absolute_error: 0.9520
# Epoch 179/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3123 - mean_absolute_error: 0.2711 - val_loss: 5.3611 - val_mean_absolute_error: 0.9495
# Epoch 180/200
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3482 - mean_absolute_error: 0.2794 - val_loss: 5.0833 - val_mean_absolute_error: 0.9326
# Epoch 181/200
# 90/90 [==============================] - 6s 68ms/step - loss: 0.3639 - mean_absolute_error: 0.2815 - val_loss: 5.0473 - val_mean_absolute_error: 0.9221
# Epoch 182/200
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3267 - mean_absolute_error: 0.2719 - val_loss: 5.1943 - val_mean_absolute_error: 0.9383
# Epoch 183/200
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2978 - mean_absolute_error: 0.2675 - val_loss: 5.3173 - val_mean_absolute_error: 0.9496
# Epoch 184/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.2765 - mean_absolute_error: 0.2623 - val_loss: 5.4836 - val_mean_absolute_error: 0.9721
# Epoch 185/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.2786 - mean_absolute_error: 0.2611 - val_loss: 5.2411 - val_mean_absolute_error: 0.9478
# Epoch 186/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3095 - mean_absolute_error: 0.2757 - val_loss: 5.0075 - val_mean_absolute_error: 0.9147
# Epoch 187/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3148 - mean_absolute_error: 0.2694 - val_loss: 5.3657 - val_mean_absolute_error: 0.9771
# Epoch 188/200
# 90/90 [==============================] - 5s 55ms/step - loss: 0.3334 - mean_absolute_error: 0.2756 - val_loss: 5.5559 - val_mean_absolute_error: 0.9877
# Epoch 189/200
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3439 - mean_absolute_error: 0.2754 - val_loss: 5.2623 - val_mean_absolute_error: 0.9419
# Epoch 190/200
# 90/90 [==============================] - 5s 56ms/step - loss: 0.3047 - mean_absolute_error: 0.2672 - val_loss: 5.1421 - val_mean_absolute_error: 0.9336
# Epoch 191/200
# 90/90 [==============================] - 5s 57ms/step - loss: 0.2991 - mean_absolute_error: 0.2658 - val_loss: 5.2822 - val_mean_absolute_error: 0.9365
# Epoch 192/200
# 90/90 [==============================] - 6s 70ms/step - loss: 0.2957 - mean_absolute_error: 0.2655 - val_loss: 5.2245 - val_mean_absolute_error: 0.9573
# Epoch 193/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.3284 - mean_absolute_error: 0.2703 - val_loss: 4.8274 - val_mean_absolute_error: 0.9018
# Epoch 194/200
# 90/90 [==============================] - 6s 70ms/step - loss: 0.2730 - mean_absolute_error: 0.2621 - val_loss: 5.1971 - val_mean_absolute_error: 0.9398
# Epoch 195/200
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2714 - mean_absolute_error: 0.2605 - val_loss: 5.2092 - val_mean_absolute_error: 0.9439
# Epoch 196/200
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3141 - mean_absolute_error: 0.2671 - val_loss: 5.2643 - val_mean_absolute_error: 0.9471
# Epoch 197/200
# 90/90 [==============================] - 5s 54ms/step - loss: 0.2737 - mean_absolute_error: 0.2615 - val_loss: 5.3176 - val_mean_absolute_error: 0.9386
# Epoch 198/200
# 90/90 [==============================] - 5s 57ms/step - loss: 0.3122 - mean_absolute_error: 0.2723 - val_loss: 5.4143 - val_mean_absolute_error: 0.9713
# Epoch 199/200
# 90/90 [==============================] - 7s 72ms/step - loss: 0.3417 - mean_absolute_error: 0.2744 - val_loss: 5.2667 - val_mean_absolute_error: 0.9539
# Epoch 200/200
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2864 - mean_absolute_error: 0.2635 - val_loss: 5.1391 - val_mean_absolute_error: 0.9496

# %%
if history_c:
    for key, vals in history_1.history.items():
        history_c.history[key] += vals
else:
    history_c = history_1

# %%
plt.plot(history_c.history['loss'], label='loss')
plt.plot(history_c.history['val_loss'], label='val_loss')
plt.plot(history_c.history['mean_absolute_error'], label='mae')
plt.legend(loc= 'upper right');

# %% [markdown]
# ## Посмотрим на восстановленные данные и сравним с исходными
# ---
# для того, чтобы восстановить и посмотреть на всю последовательность, мы агрегируем оконные восстановленные последовательности. Т.е. усредним показатели на данный момент времени, полученные из разных окон после применения автоэнкодера.

# %%
# сформируем весь датасет в виде torch.Tensor
all_x = []

for x1, y1 in all_data.dataset:
    all_x.append(x1)

all_data_batch = tf.concat(all_x, axis=0)
rec_data_batch = cnn_ae(all_data_batch)

all_data_batch.shape, rec_data_batch.shape
# Out:
# (TensorShape([5022, 31, 5]), TensorShape([5022, 31, 2]))

# %%
def aggregate_predictions(y_hat_batch):
    """
    Aggregates predictions for each timestep. When predicting n steps
    ahead where n > 1, these are multiple predictions for a timestep.
    Args:
        y_hat_batch (np.arr): predictions shape (<batch length>, <n_preds)
    """
    # initialization
    n_times = y_hat_batch.shape[0]
    n_preds = y_hat_batch.shape[1]
    agg_y_hat = np.zeros(shape=(n_times + n_preds - 1,))
    temp_y_hat = np.zeros(shape=(n_times + n_preds - 1, n_preds))
    # сдвинем i-й столбец y_hat_batch на i позиций вниз в temp_y_hat
    # так чтобы в j-й строке были все прогнозы для j-го момента времени
    for col in range(y_hat_batch.shape[1]):
        temp_y_hat[col: col + n_times, col] = y_hat_batch[:, col]

    # вычислим среднее по каждому моменту времени
    agg_y_hat = np.mean(temp_y_hat, axis=1)

    # поправим хвосты
    for row in range(n_preds-1):
        agg_y_hat[row] = np.mean(temp_y_hat[row, 0:row+1])
        agg_y_hat[-row-1] = np.mean(temp_y_hat[-row-1, -row-1:])

    return agg_y_hat, temp_y_hat

# %% [markdown]
# Объединим реконструированный сигнал усреднением по всем окнам

# %%
rec_data_list = []
for i, index in enumerate(goal_indexes):
    np_reconstr_data_batch = rec_data_batch[:, :, i].numpy()
    agg_reconstr_data, temp_reconstr_data = aggregate_predictions(np_reconstr_data_batch)
    rec_data_list.append(agg_reconstr_data.reshape(-1, 1))

# их надо демасштабировать
rec_goal_data = np.concatenate(rec_data_list, axis=1)
rec_descale_data = dollar_scaler.inverse_transform(rec_goal_data)

np_reconstr_data_batch.shape, agg_reconstr_data.shape, rec_descale_data.shape
# Out:
# ((5022, 31), (5052,), (5052, 2))

# %% [markdown]
# посмотрим на восстановленные данные

# %%
#plt.figure(figsize=(16, 16))
n_points=300  # кол-во анализируемых последних точек (в тестовом диапазоне)

fig, ax = plt.subplots(len(goal_indexes), 1, figsize=(20, 16))

for i, index in enumerate(goal_indexes):
    ax[index].plot(df.index[-n_points:], rec_descale_data[-n_points:, i], c='blue', label='reconstr_x')
    ax[index].plot(df.index[-n_points:], df.iloc[-n_points:, index], c='red', label=goal_features[i])
plt.legend()
plt.show()

# %% [markdown]
# ## **Кластеризуем окна (k-means, agglomerative, ward, DBSCAN, ...)**
# ---

# %% [markdown]
# **Кодируем энкодером последовательности**

# %%
codes = []

for x1, y1 in all_data.dataset:
    code = encoder(x1)
    codes.append(code.numpy().reshape(1, -1))

all_codes = np.concatenate(codes, axis=0)
all_codes.shape
# Out:
# (5022, 32)

# %% [markdown]
# ## **Делаем проекцию tSNE и визуализируем структуру кодов**
# ---

# %%
from sklearn.manifold import TSNE

X = all_codes
tsne = TSNE(n_components=2, perplexity=45)
X_tsne = tsne.fit_transform(X)
X_tsne.shape
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (5022, 2)

# %%
plt.figure(figsize=(12,10))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
plt.title('t-SNE проецирование кодов последовательностей');

# %% [markdown]
# ## Выполним кластеризацию и проанализируем получившуюся структуру кластеров
# ---

# %% [markdown]
# ### Метод kmeans++.
# ---
# Определим оптимальное кол-во кластеров

# %%
# Применение k-means
from sklearn.cluster import KMeans
from sklearn import metrics

X = all_codes
k_start = 2
k_end = 25

crit2 = []
for k in range(k_start, k_end + 1):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
    kmeans.fit(X)
    crit2.append(metrics.silhouette_score(X, kmeans.labels_))

plt.plot(range(k_start, k_end + 1), crit2)
plt.xlabel('K - количество кластеров')
plt.title('Зависимость коэффициента силуэта разбиения k-means от K');

# %%
kmeans = KMeans(n_clusters=6, init='k-means++', n_init=15, random_state=123)

# применяем - обучаем
kmeans.fit(X)
# метки кластеров
labels = kmeans.labels_
# визуализируем получившееся разбиение с учетом знания цифр на картинках
# и сравним с разбиением на кластеры, полученным с помощью k-means
plt.figure(figsize=(12,5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels)
plt.colorbar()
plt.title('Структура кластеров k-means (tSNE)')
plt.show()

# %%
pd.Series(labels).value_counts()
# Out:
# 1    2094
# 2    1798
# 0     857
# 4     219
# 5      30
# 3      24
# dtype: int64

# %% [markdown]
# Проанализируем примеры последовательностей из разных кластеров

# %%
centers_code = tf.Variable(kmeans.cluster_centers_, dtype=tf.float32)
centers_code = tf.reshape(centers_code, (*centers_code.shape, 1))
centers_seq = decoder(centers_code)
np_centers_seq = centers_seq.numpy()
centers_code.shape, centers_seq.shape, np_centers_seq.shape
# Out:
# (TensorShape([6, 32, 1]), TensorShape([6, 31, 2]), (6, 31, 2))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(13, 6))

# визуализируем получившиеся последовательности
for index in goal_indexes:
    ax[index].set_title(df.columns[index])
    for label in np.unique(labels):
        ax[index].plot(range(win_width), np_centers_seq[label, :, index].ravel(), label=str(label))
        ax[index].legend()

fig.show()

# %% [markdown]
# ### Метод DBSCAN
# ---
#
# Этот метод интересен тем, что он может помочь выявить аномалии

# %%
from sklearn.cluster import DBSCAN

X = all_codes

# %%
# применим силуэтный анализ
n_start = 5
n_end = 50
n_step = 2

crit3 = []
for n in range(n_start, n_end + 1, n_step):
    dbscan = DBSCAN(eps=5.0, min_samples=n, metric='euclidean',  algorithm='auto')
    dbscan.fit(X)
    X1 = X[dbscan.labels_ != -1]
    labels_1 = dbscan.labels_[dbscan.labels_ != -1]
    crit3.append(metrics.silhouette_score(X1, labels_1) * len(np.unique(labels_1)) * len(X1) / len(X))

plt.plot(range(n_start, n_end + 1, n_step), crit3)
plt.xlabel('n - минимальное количество объектов в окружности')
plt.title('Зависимость коэффициента силуэта разбиения DBSCAN от n=min_samples');

# %%
# применим силуэтный анализ
eps_start = 3
eps_end = 10
eps_step = 0.5

crit3 = []
for eps in np.arange(eps_start, eps_end + 1, eps_step):
    dbscan = DBSCAN(eps=eps, min_samples=10, metric='euclidean',  algorithm='auto')
    dbscan.fit(X)
    X1 = X[dbscan.labels_ != -1]
    labels_1 = dbscan.labels_[dbscan.labels_ != -1]
    crit3.append(metrics.silhouette_score(X1, labels_1) * len(np.unique(labels_1)) * len(X1) / len(X))

plt.plot(np.arange(eps_start, eps_end + 1, eps_step), crit3)
plt.xlabel('n - минимальное количество объектов в окружности')
plt.title('Зависимость коэффициента силуэта разбиения DBSCAN от eps');

# %% [markdown]
# выберем значения параметров

# %%
dbscan = DBSCAN(eps=4.0, min_samples=35, metric='euclidean',  algorithm='auto')
dbscan.fit(X)
labels_1 = dbscan.labels_
pd.Series(labels_1).value_counts()
# Out:
# -1    2346
#  0    1747
#  1     764
#  2     165
# dtype: int64

# %%
# визуализируем получившееся разбиение с учетом знания цифр на картинках
# и сравним с разбиением на кластеры, полученным с помощью k-means
plt.figure(figsize=(12,5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels_1)
plt.colorbar()
plt.title('Структура кластеров DBSCAN (tSNE)')
plt.show()

# %% [markdown]
# проанализируем примеры последовательностей из разных кластеров

# %%
labels_1 = dbscan.labels_[dbscan.labels_ != -1]
cluster_centers = np.array([X[dbscan.labels_ == label].mean(axis=0) for label in range(max(dbscan.labels_)+1)])
cluster_centers.shape
# Out:
# (3, 20)

# %%
centers_code = tf.Variable(cluster_centers, dtype=tf.float32)
centers_code = tf.reshape(centers_code, (*centers_code.shape, 1))
centers_seq = decoder(centers_code)
np_centers_seq = centers_seq.numpy()
centers_code.shape, centers_seq.shape, np_centers_seq.shape
# Out:
# <ipython-input-572-f2485d35cc10>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   centers_code = torch.tensor(torch.from_numpy(cluster_centers), dtype=torch.float32, device=device)
# (torch.Size([3, 20]), torch.Size([3, 5, 31]), (3, 5, 31))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(13, 6))

# визуализируем получившиеся последовательности
for index in goal_indexes:
    ax[index].set_title(df.columns[index])
    for label in np.unique(labels):
        ax[index].plot(range(win_width), np_centers_seq[label, :, index].ravel(), label=str(label))
        ax[index].legend()

fig.show()

# %% [markdown]
# ### Иерархическая кластеризация
# ---

# %%
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram

X = all_codes

Z = linkage(X, method='ward', metric='euclidean')

dend = dendrogram(Z, orientation='left', color_threshold=0.0)

# %%
labels_2 = fcluster(Z, 150, criterion='distance')
pd.Series(labels_2).value_counts()
# Out:
# 2    2061
# 3    1073
# 4    1016
# 6     739
# 1      78
# 5      25
# 8      18
# 7      12
# dtype: int64

# %%
# визуализируем получившееся разбиение с учетом знания цифр на картинках
# и сравним с разбиением на кластеры, полученным с помощью k-means
plt.figure(figsize=(12,5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels_2, cmap=plt.cm.Spectral)
plt.colorbar()
plt.title('Структура кластеров DBSCAN (tSNE)')
plt.show()

# %% [markdown]
# ## **Сохранение обученной модели**
# ------

# %%
model_name = 'cnn_ae-seq' + str(win_width) + '-ls' + str(latent_dim) + '_k' + '-'.join([str(k) for k in kernels]) + '-2'
print(model_name)
cnn_ae.save(path + 'models/' + model_name)
# Out:
# cnn_ae-seq31-ls32_k5-3-2
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
